# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import numpy as np
import random as random

# Study data files
education = "Index Education.csv"
education = pd.read_csv(education)
education.head(40)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6120fe0a0c4f> in <module>
#       8 # Study data files
#       9 education = "Index Education.csv"
# ---> 10 education = pd.read_csv(education)
#      11 education.head(40)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Index Education.csv' does not exist: b'Index Education.csv'

# %%
#Filter Education Code - School enrollment, primary (% gross)

education = education.loc[education["Indicator Code"] =="SE.PRM.ENRR", :]
education.head()
# Out:
#     Country Name Country Code                        Indicator Name  \
# 122        Aruba          ABW  School enrollment, primary (% gross)
# 276  Afghanistan          AFG  School enrollment, primary (% gross)
# 430       Angola          AGO  School enrollment, primary (% gross)
# 584      Albania          ALB  School enrollment, primary (% gross)
# 738      Andorra          AND  School enrollment, primary (% gross)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 122    SE.PRM.ENRR   NaN   NaN   NaN   NaN   NaN   NaN  ...  113.79430
# 276    SE.PRM.ENRR   NaN   NaN   NaN   NaN   NaN   NaN  ...  100.07170
# 430    SE.PRM.ENRR   NaN   NaN   NaN   NaN   NaN   NaN  ...  105.78100
# 584    SE.PRM.ENRR   NaN   NaN   NaN   NaN   NaN   NaN  ...   93.49047
# 738    SE.PRM.ENRR   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
#
#           2011       2012       2013      2014      2015      2016      2017  \
# 122  105.25590  104.08710  116.03930  117.1081       NaN       NaN       NaN
# 276   97.64164  103.49240  104.49840  105.9197  105.7785       NaN  102.3105
# 430  119.53010        NaN        NaN       NaN  113.4780       NaN       NaN
# 584   95.00608   97.58513   99.98391  104.1080  105.5430  105.5539  107.0466
# 738        NaN        NaN        NaN       NaN       NaN       NaN       NaN
#
#          2018  2019
# 122       NaN   NaN
# 276       NaN   NaN
# 430       NaN   NaN
# 584  106.9934   NaN
# 738       NaN   NaN
#
# [5 rows x 64 columns]

# %%
#Filter Country Code - BRA and MEX
educationBRMX = education.loc[(education["Country Code"] =="MEX") | (education["Country Code"] =="BRA")]
educationBRMX
# Out:
#       Country Name Country Code                        Indicator Name  \
# 4280        Brazil          BRA  School enrollment, primary (% gross)
# 23530       Mexico          MEX  School enrollment, primary (% gross)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...      2010  \
# 4280     SE.PRM.ENRR   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 23530    SE.PRM.ENRR   NaN   NaN   NaN   NaN   NaN   NaN  ...  110.6335
#
#            2011      2012      2013      2014      2015      2016      2017  \
# 4280   132.4966  134.5204  113.9198  114.2547  112.7733  113.9454  115.4478
# 23530  110.5408  110.4135  109.4415  108.0058  106.6061  106.2777  105.7700
#
#        2018  2019
# 4280    NaN   NaN
# 23530   NaN   NaN
#
# [2 rows x 64 columns]

# %%
#Select Columns
df = educationBRMX[["Country Code", "2006","2007","2008","2009","2010","2011","2012", "2013", "2014", "2015", "2016"]]
#df = df.dropna()
df
# Out:
#       Country Code       2006       2007       2008       2009      2010  \
# 4280           BRA        NaN  128.17979  132.05521  131.16516       NaN
# 23530          MEX  108.17477  108.79971  109.42442  110.54528  110.6335
#
#            2011      2012      2013      2014      2015      2016
# 4280   132.4966  134.5204  113.9198  114.2547  112.7733  113.9454
# 23530  110.5408  110.4135  109.4415  108.0058  106.6061  106.2777

# %%
#Transpose columns
new_df = pd.melt(df,id_vars=["Country Code"],value_vars=["2006","2007","2008","2009","2010","2011","2012", "2013", "2014", "2015", "2016"], var_name = "Year",value_name="Education Index")
new_df
# Out:
#    Country Code  Year  Education Index
# 0           BRA  2006              NaN
# 1           MEX  2006        108.17477
# 2           BRA  2007        128.17979
# 3           MEX  2007        108.79971
# 4           BRA  2008        132.05521
# 5           MEX  2008        109.42442
# 6           BRA  2009        131.16516
# 7           MEX  2009        110.54528
# 8           BRA  2010              NaN
# 9           MEX  2010        110.63350
# 10          BRA  2011        132.49660
# 11          MEX  2011        110.54080
# 12          BRA  2012        134.52040
# 13          MEX  2012        110.41350
# 14          BRA  2013        113.91980
# 15          MEX  2013        109.44150
# 16          BRA  2014        114.25470
# 17          MEX  2014        108.00580
# 18          BRA  2015        112.77330
# 19          MEX  2015        106.60610
# 20          BRA  2016        113.94540
# 21          MEX  2016        106.27770
